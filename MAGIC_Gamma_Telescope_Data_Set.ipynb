# %% [markdown]
# <a href="https://colab.research.google.com/github/Dubaifinest/Dubaifinest/blob/main/MAGIC_Gamma_Telescope_Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# #Data Set
#
# The data are MC generated (see below) to simulate registration of high energy gamma particles in a ground-based atmospheric Cherenkov gamma telescope using the imaging technique. Cherenkov gamma telescope observes high energy gamma rays, taking advantage of the radiation emitted by charged particles produced inside the electromagnetic showers initiated by the gammas, and developing in the atmosphere. This Cherenkov radiation (of visible to UV wavelengths) leaks through the atmosphere and gets recorded in the detector, allowing reconstruction of the shower parameters. The available information consists of pulses left by the incoming Cherenkov photons on the photomultiplier tubes, arranged in a plane, the camera. Depending on the energy of the primary gamma, a total of few hundreds to some 10000 Cherenkov photons get collected, in patterns (called the shower image), allowing to discriminate statistically those caused by primary gammas (signal) from the images of hadronic showers initiated by cosmic rays in the upper atmosphere (background).
#
# Typically, the image of a shower after some pre-processing is an elongated cluster. Its long axis is oriented towards the camera center if the shower axis is parallel to the telescope's optical axis, i.e. if the telescope axis is directed towards a point source. A principal component analysis is performed in the camera plane, which results in a correlation axis and defines an ellipse. If the depositions were distributed as a bivariate Gaussian, this would be an equidensity ellipse. The characteristic parameters of this ellipse (often called Hillas parameters) are among the image parameters that can be used for discrimination. The energy depositions are typically asymmetric along the major axis, and this asymmetry can also be used in discrimination. There are, in addition, further discriminating characteristics, like the extent of the cluster in the image plane, or the total sum of depositions.
#
# The data set was generated by a Monte Carlo program, Corsika, described in:
# D. Heck et al., CORSIKA, A Monte Carlo code to simulate extensive air showers,
# Forschungszentrum Karlsruhe FZKA 6019 (1998).
#
# Original Owner:
#
# R. K. Bock
# Major Atmospheric Gamma Imaging Cherenkov Telescope project (MAGIC)
# http://wwwmagic.mppmu.mpg.de
# rkb '@' mail.cern.ch
#
# Donor:
#
# P. Savicky
# Institute of Computer Science, AS of CR
# Czech Republic
# savicky '@' cs.cas.cz

# %%
cols=["fLenth", "fWidth", "fSize", "fConc", "fConcl", "fAsym", "fM3Long", "fM3Trans", "fAlpha", "fDist", "class"]
df = pd.read_csv("magic04.data", names=cols)
df.head()
# Out:
#      fLenth    fWidth   fSize   fConc  fConcl     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
df["class"] = (df["class"] == "g").astype(int)

# %%
df.head()
# Out:
#      fLenth    fWidth   fSize   fConc  fConcl     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist  class
# 0  40.0920   81.8828      1
# 1   6.3609  205.2610      1
# 2  76.9600  256.7880      1
# 3  10.4490  116.7370      1
# 4   4.6480  356.4620      1

# %%
for label in cols[:-1]:
  plt.hist(df[df["class"]==1][label], color='blue', label='gamma', alpha=0.7, density=True)
  plt.hist(df[df["class"]==0][label], color='red', label='hadron', alpha=0.7, density=True)
  plt.title(label)
  plt.ylabel("probability")
  plt.xlabel(label)
  plt.legend()
  plt.show()

# %% [markdown]
# #Train, Validation, Test Datasets

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)), int(0.8*len(df))])

# %%
def scale_dataset(dataframe, oversample=False):
  x = dataframe[dataframe.columns[:-1]].values
  y = dataframe[dataframe.columns[-1]].values

  scaler = StandardScaler()
  x = scaler.fit_transform(x)

  if oversample:
    ros = RandomOverSampler()
    x, y = ros.fit_resample(x, y)

  data = np.hstack((x, np.reshape(y, (-1, 1))))

  return data, x, y

# %%
train, x_train, y_train = scale_dataset(train, oversample=True)
valid, x_valid, y_valid = scale_dataset(valid, oversample=False)
test, x_test, y_test = scale_dataset(test, oversample=False)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn_model.predict(x_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75      1310
#            1       0.87      0.87      0.87      2494
#
#     accuracy                           0.83      3804
#    macro avg       0.81      0.81      0.81      3804
# weighted avg       0.83      0.83      0.83      3804

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_model = GaussianNB()
nb_model =nb_model.fit(x_train, y_train)

# %%
y_pred = nb_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.41      0.51      1310
#            1       0.74      0.90      0.81      2494
#
#     accuracy                           0.73      3804
#    macro avg       0.71      0.65      0.66      3804
# weighted avg       0.72      0.73      0.71      3804

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_model = LogisticRegression()
lg_model =lg_model.fit(x_train, y_train)

# %%
y_pred = lg_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.73      0.71      1310
#            1       0.85      0.82      0.84      2494
#
#     accuracy                           0.79      3804
#    macro avg       0.77      0.78      0.77      3804
# weighted avg       0.79      0.79      0.79      3804

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()
svm_model =svm_model.fit(x_train, y_train)

# %%
y_pred = svm_model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81      1310
#            1       0.89      0.91      0.90      2494
#
#     accuracy                           0.87      3804
#    macro avg       0.86      0.85      0.85      3804
# weighted avg       0.87      0.87      0.87      3804

# %% [markdown]
# # Neural Network ( Tensor Flow)

# %%
import tensorflow as tf
from keras.callbacks import EarlyStopping

# %%
def plot_history(history):
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
  ax1.plot(history.history['loss'], label='loss')
  ax1.plot(history.history['val_loss'], label='val_loss')
  ax1.set_xlabel('Epoch')
  ax1.set_ylabel('Binary crossentropy')
  ax1.grid(True)

  ax2.plot(history.history['accuracy'], label='accuracy')
  ax2.plot(history.history['val_accuracy'], label='val_accuracy')
  ax2.set_xlabel('Epoch')
  ax2.set_ylabel('accuracy')
  ax2.grid(True)

  plt.show()

# %%
plot_history(history)

# %%
def train_model(x_train, y_train, num_nodes, dropout_prob, lr, batch_size, epochs):
  nn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(num_nodes, activation = 'relu', input_shape=(10,)),
    tf.keras.layers.Dropout(dropout_prob),
    tf.keras.layers.Dense(num_nodes, activation = 'relu'),
    tf.keras.layers.Dropout(dropout_prob),
    tf.keras.layers.Dense(1, activation = 'sigmoid')
  ])

  nn_model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss='binary_crossentropy',
                 metrics=['accuracy'])
  history = nn_model.fit(
    x_train, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=0
  )
  return nn_model, history

# %%
least_val_loss = None
least_loss_model = None
epochs=100
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

for num_nodes in [16, 32, 64]:
    for dropout_prob in [0, 0.2]:
        for lr in [0.01, 0.005, 0.001]:
            for batch_size in [32, 64, 128]:
                model, history = train_model(x_train, y_train, num_nodes, dropout_prob, lr, batch_size, epochs)
                model.fit(x_train, y_train, validation_data=(x_valid, y_valid), callbacks=[early_stopping])
                val_loss = model.evaluate(x_valid, y_valid)
                if least_val_loss is None or val_loss < least_val_loss:
                    least_val_loss = val_loss
                    least_loss_model = model
                    model.save('best_model.h5')
# Out:
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3064 - accuracy: 0.8621 - val_loss: 0.3442 - val_accuracy: 0.8544
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3442 - accuracy: 0.8544
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3111 - accuracy: 0.8606 - val_loss: 0.3271 - val_accuracy: 0.8625
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3271 - accuracy: 0.8625
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3177 - accuracy: 0.8592 - val_loss: 0.3550 - val_accuracy: 0.8467
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3550 - accuracy: 0.8467
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3061 - accuracy: 0.8585 - val_loss: 0.3400 - val_accuracy: 0.8546
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8546
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3123 - accuracy: 0.8603 - val_loss: 0.3485 - val_accuracy: 0.8562
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3485 - accuracy: 0.8562
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3243 - accuracy: 0.8585 - val_loss: 0.3413 - val_accuracy: 0.8570
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3413 - accuracy: 0.8570
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3080 - accuracy: 0.8589 - val_loss: 0.3356 - val_accuracy: 0.8620
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.8620
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3111 - accuracy: 0.8601 - val_loss: 0.3332 - val_accuracy: 0.8578
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3332 - accuracy: 0.8578
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3225 - accuracy: 0.8555 - val_loss: 0.3298 - val_accuracy: 0.8615
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.8615
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3557 - accuracy: 0.8401 - val_loss: 0.3337 - val_accuracy: 0.8675
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3337 - accuracy: 0.8675
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3597 - accuracy: 0.8373 - val_loss: 0.3329 - val_accuracy: 0.8641
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3329 - accuracy: 0.8641
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3604 - accuracy: 0.8407 - val_loss: 0.3382 - val_accuracy: 0.8675
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3382 - accuracy: 0.8675
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3576 - accuracy: 0.8423 - val_loss: 0.3390 - val_accuracy: 0.8617
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8617
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3593 - accuracy: 0.8411 - val_loss: 0.3371 - val_accuracy: 0.8591
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3371 - accuracy: 0.8591
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3634 - accuracy: 0.8397 - val_loss: 0.3446 - val_accuracy: 0.8557
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3446 - accuracy: 0.8557
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3596 - accuracy: 0.8380 - val_loss: 0.3395 - val_accuracy: 0.8623
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3395 - accuracy: 0.8623
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3601 - accuracy: 0.8424 - val_loss: 0.3593 - val_accuracy: 0.8578
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3593 - accuracy: 0.8578
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3647 - accuracy: 0.8375 - val_loss: 0.3409 - val_accuracy: 0.8612
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8612
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2775 - accuracy: 0.8785 - val_loss: 0.3324 - val_accuracy: 0.8609
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8609
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2898 - accuracy: 0.8723 - val_loss: 0.3250 - val_accuracy: 0.8649
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3250 - accuracy: 0.8649
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3009 - accuracy: 0.8658 - val_loss: 0.3352 - val_accuracy: 0.8651
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8651
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2758 - accuracy: 0.8781 - val_loss: 0.3458 - val_accuracy: 0.8604
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3458 - accuracy: 0.8604
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8708 - val_loss: 0.3301 - val_accuracy: 0.8620
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8620
# 461/461 [==============================] - 1s 2ms/step - loss: 0.3046 - accuracy: 0.8625 - val_loss: 0.3483 - val_accuracy: 0.8546
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3483 - accuracy: 0.8546
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2758 - accuracy: 0.8751 - val_loss: 0.3258 - val_accuracy: 0.8641
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3258 - accuracy: 0.8641
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2911 - accuracy: 0.8678 - val_loss: 0.3292 - val_accuracy: 0.8609
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3292 - accuracy: 0.8609
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3027 - accuracy: 0.8646 - val_loss: 0.3445 - val_accuracy: 0.8565
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3445 - accuracy: 0.8565
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3252 - accuracy: 0.8554 - val_loss: 0.3190 - val_accuracy: 0.8722
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8722
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3272 - accuracy: 0.8542 - val_loss: 0.3198 - val_accuracy: 0.8707
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3198 - accuracy: 0.8707
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3344 - accuracy: 0.8511 - val_loss: 0.3256 - val_accuracy: 0.8704
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8704
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3248 - accuracy: 0.8589 - val_loss: 0.3274 - val_accuracy: 0.8633
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8633
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3301 - accuracy: 0.8527 - val_loss: 0.3326 - val_accuracy: 0.8743
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3326 - accuracy: 0.8743
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3354 - accuracy: 0.8502 - val_loss: 0.3256 - val_accuracy: 0.8654
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3256 - accuracy: 0.8654
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3212 - accuracy: 0.8572 - val_loss: 0.3190 - val_accuracy: 0.8730
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3190 - accuracy: 0.8730
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3278 - accuracy: 0.8544 - val_loss: 0.3249 - val_accuracy: 0.8654
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3249 - accuracy: 0.8654
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3373 - accuracy: 0.8528 - val_loss: 0.3352 - val_accuracy: 0.8594
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8594
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2280 - accuracy: 0.9008 - val_loss: 0.3761 - val_accuracy: 0.8457
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.8457
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2624 - accuracy: 0.8821 - val_loss: 0.3539 - val_accuracy: 0.8528
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3539 - accuracy: 0.8528
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2862 - accuracy: 0.8688 - val_loss: 0.3920 - val_accuracy: 0.8417
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.8417
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2348 - accuracy: 0.8955 - val_loss: 0.3452 - val_accuracy: 0.8641
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3452 - accuracy: 0.8641
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2630 - accuracy: 0.8819 - val_loss: 0.3345 - val_accuracy: 0.8644
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8644
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2879 - accuracy: 0.8715 - val_loss: 0.3936 - val_accuracy: 0.8336
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8336
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2364 - accuracy: 0.8968 - val_loss: 0.3788 - val_accuracy: 0.8457
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8457
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2640 - accuracy: 0.8846 - val_loss: 0.3361 - val_accuracy: 0.8657
# 119/119 [==============================] - 0s 3ms/step - loss: 0.3361 - accuracy: 0.8657
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2838 - accuracy: 0.8715 - val_loss: 0.3576 - val_accuracy: 0.8546
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3576 - accuracy: 0.8546
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2990 - accuracy: 0.8686 - val_loss: 0.3128 - val_accuracy: 0.8751
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3128 - accuracy: 0.8751
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3058 - accuracy: 0.8663 - val_loss: 0.3438 - val_accuracy: 0.8552
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8552
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3165 - accuracy: 0.8574 - val_loss: 0.3195 - val_accuracy: 0.8680
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3195 - accuracy: 0.8680
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2907 - accuracy: 0.8726 - val_loss: 0.3397 - val_accuracy: 0.8609
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3397 - accuracy: 0.8609
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3060 - accuracy: 0.8651 - val_loss: 0.3549 - val_accuracy: 0.8507
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3549 - accuracy: 0.8507
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3153 - accuracy: 0.8587 - val_loss: 0.3323 - val_accuracy: 0.8601
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3323 - accuracy: 0.8601
# 461/461 [==============================] - 1s 3ms/step - loss: 0.2951 - accuracy: 0.8689 - val_loss: 0.3130 - val_accuracy: 0.8746
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3130 - accuracy: 0.8746
# 461/461 [==============================] - 1s 3ms/step - loss: 0.3084 - accuracy: 0.8616 - val_loss: 0.3169 - val_accuracy: 0.8641
# 119/119 [==============================] - 0s 2ms/step - loss: 0.3169 - accuracy: 0.8641
# 461/461 [==============================] - 2s 3ms/step - loss: 0.3149 - accuracy: 0.8599 - val_loss: 0.3259 - val_accuracy: 0.8638
# 119/119 [==============================] - 0s 1ms/step - loss: 0.3259 - accuracy: 0.8638

# %%
least_loss_model.predict(x_test)
# Out:
# 119/119 [==============================] - 0s 1ms/step
# array([[1.8538412e-05],
#        [6.4530957e-01],
#        [9.9217200e-01],
#        ...,
#        [9.5844960e-01],
#        [8.9452237e-01],
#        [3.5541579e-01]], dtype=float32)

# %%
y_pred = least_loss_model.predict(x_test)
y_pred = (y_pred > 0.5).astype(int).reshape(-1,)
# Out:
# 119/119 [==============================] - 0s 2ms/step

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 0])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81      1310
#            1       0.89      0.92      0.91      2494
#
#     accuracy                           0.88      3804
#    macro avg       0.87      0.86      0.86      3804
# weighted avg       0.87      0.88      0.87      3804
